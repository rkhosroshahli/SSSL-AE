# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from sklearn.metrics import f1_score

import matplotlib.pyplot as plt

# %%
# Model / data parameters
num_classes = 10
input_shape = (28, 28, 1)
ndim=28

# Load the data and split it between train and test sets
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

# Scale images to the [0, 1] range
x_train = x_train.astype("float32") / 255
x_test = x_test.astype("float32") / 255
# Make sure images have shape (28, 28, 1)
x_train = np.expand_dims(x_train, -1)
x_test = np.expand_dims(x_test, -1)
print("x_train shape:", x_train.shape)
print(x_train.shape[0], "train samples")
print(x_test.shape[0], "test samples")


# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples

# %%
fashion_mnist = tf.keras.datasets.fashion_mnist

(X_train_fs, y_train_fs), (X_test_fs, y_test_fs) = fashion_mnist.load_data()
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
fig, axarr = plt.subplots(1,6, figsize=(10,8))
for i in range(len(axarr)-3):
    axarr[i].imshow(x_train[i].reshape(ndim,ndim), cmap='gist_gray')
    axarr[i].set_title(f"Label={y_train[i].argmax()}")
    axarr[i].yaxis.set_visible(False)
    axarr[i].xaxis.set_visible(False)
    
for i in range(len(axarr)-3, len(axarr)):
    axarr[i].imshow(X_train_fs[i].reshape(ndim,ndim), cmap='gist_gray')
    axarr[i].set_title(f"Label={class_names[y_train_fs[i]]}")
    axarr[i].yaxis.set_visible(False)
    axarr[i].xaxis.set_visible(False)

# %%
def unison_shuffled_copies(a, b):
    assert len(a) == len(b)
    p = np.random.permutation(len(a))
    return a[p], b[p]

# %%
from sklearn.neighbors import KNeighborsClassifier
def run_classifier(x_train_classifer, y_train_classifer, x_test_classifer, y_test_classifer):
        clf = KNeighborsClassifier(10)
        clf.fit(x_train_classifer.reshape((len(x_train_classifer), ndim*ndim)), y_train_classifer)

        y_pred = clf.predict(x_train_classifer.reshape((len(x_train_classifer), ndim*ndim)))
        clf_train_f1 = f1_score(y_train_classifer, y_pred, average='macro')
        y_pred = clf.predict(x_test_classifer.reshape((len(x_test_classifer), ndim*ndim)))
        clf_test_f1 = f1_score(y_test_classifer, y_pred, average='macro')

        print(f"Train F1-score= {(clf_train_f1):.3e}")
        print(f"Test F1-score= {(clf_test_f1):.3e}")
        
        return clf_train_f1, clf_test_f1

# %%
step=1
mean=0
std=0.05
noise_factor=1.0

# %%
autoencoder=keras.models.load_model('mnist_50epoch_128batch_50000train_autoencoder.h5')
encoder=keras.models.load_model('mnist_50epoch_128batch_50000train_encoder.h5')
decoder=keras.models.load_model('mnist_50epoch_128batch_50000train_decoder.h5')
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
img_per_class=10

labeled_train_data_counter=np.zeros(10)
labeled_train_data_indices=np.ones((10,img_per_class))*-1
for i, y in enumerate(y_train[50000:]):
    if labeled_train_data_counter.sum() == img_per_class*10:
        break
    y_arg = y.argmax()
    counter= int(labeled_train_data_counter[y_arg])
    if counter >= img_per_class:
        continue
    if labeled_train_data_indices[y_arg, counter] == -1:
        labeled_train_data_counter[y_arg] +=1
        labeled_train_data_indices[y_arg, counter] = i
        
labeled_train_data_indices=labeled_train_data_indices.astype(int)+50000

indices=labeled_train_data_indices.flatten('F')
x_train_classifer=x_train[indices].copy()
y_train_classifer=y_train[indices].copy().argmax(axis=1)

x_test_classifer=x_test.copy()
y_test_classifer=y_test.copy().argmax(axis=1)

print(x_train_classifer.shape)

hist_clf_train_f1, hist_clf_test_f1=[], []

clf_train_f1, clf_test_f1=run_classifier(x_train_classifer, y_train_classifer,
                                         x_test_classifer, y_test_classifer)
hist_clf_train_f1.append(clf_train_f1)
hist_clf_test_f1.append(clf_test_f1)
# Out:
# (100, 28, 28, 1)
# Train F1-score= 7.063e-01
# Test F1-score= 6.122e-01

# %%
labeled_train_data_indices
# Out:
# array([[50018, 50024, 50026, 50036, 50042, 50057, 50061, 50070, 50072,
#         50081],
#        [50016, 50023, 50032, 50051, 50055, 50056, 50062, 50063, 50068,
#         50083],
#        [50011, 50028, 50052, 50065, 50085, 50096, 50105, 50153, 50167,
#         50196],
#        [50000, 50007, 50012, 50025, 50033, 50043, 50045, 50067, 50087,
#         50107],
#        [50005, 50009, 50014, 50022, 50031, 50049, 50050, 50069, 50080,
#         50089],
#        [50006, 50010, 50017, 50019, 50060, 50071, 50091, 50111, 50138,
#         50142],
#        [50002, 50004, 50027, 50034, 50039, 50058, 50059, 50073, 50076,
#         50082],
#        [50021, 50037, 50038, 50046, 50047, 50064, 50066, 50075, 50095,
#         50100],
#        [50001, 50008, 50013, 50015, 50035, 50040, 50044, 50048, 50054,
#         50074],
#        [50003, 50020, 50029, 50030, 50041, 50053, 50078, 50079, 50084,
#         50088]])

# %%
def plot_orig_recon_imgs(labeled_img, noised_img, iteration, y_true):
    fig, axarr = plt.subplots(1,2)
    axarr[0].imshow(labeled_img, cmap='gist_gray')
    axarr[0].set_title("Original Image")
    axarr[0].yaxis.set_visible(False)
    axarr[0].xaxis.set_visible(False)
    axarr[1].imshow(noised_img[0], cmap='gist_gray')
    axarr[1].set_title("Reconstructed Image")
    axarr[1].yaxis.set_visible(False)
    axarr[1].xaxis.set_visible(False)
    fig.suptitle(f"Iteration {iteration}, Image Label: {y_true}")
    fig.savefig(f"plots/iteration{iteration}")
    # plt.show()
    plt.close()

# %%
idx=0
iteration=0

# %%
# x_unseen=x_train[50000:].copy()
# y_unseen=y_train[50000:].copy().argmax(axis=1)
rejected_counter=0
accepted_counter=0

while iteration < 10000:

    iteration+=1
    print(f"Iteration {iteration}:")
    
    train_size=x_train_classifer.shape[0]
    print("Train dataset size=", train_size)
    
    # random_idx=np.random.choice(10*img_per_class, 1)[0]
    idx=idx%(10*img_per_class)
    random_idx=idx
    print(random_idx)
    labeled_img = x_train_classifer[random_idx]
    encoded_data = encoder.predict(np.array([labeled_img]), verbose=0)
    noise_data = noise_factor * np.random.normal(mean, std, size=encoded_data.shape)
    perturbed_data = noise_data+encoded_data
    noised_img = decoder.predict(perturbed_data, verbose=0)
        
    plot_orig_recon_imgs(labeled_img, noised_img, iteration, y_train_classifer[random_idx])
    
    x_train_classifer = np.concatenate([x_train_classifer, noised_img], axis=0)
    y_train_classifer = np.concatenate([y_train_classifer, [y_train_classifer[random_idx]]])
    
    if iteration % 1000==0:
        clf_train_f1, clf_test_f1=run_classifier(x_train_classifer, y_train_classifer,
                                                 x_test_classifer, y_test_classifer)
        hist_clf_train_f1.append(clf_train_f1)
        hist_clf_test_f1.append(clf_test_f1)

    idx+=1
# Out:
# Iteration 1:
# Train dataset size= 100
# 0
# Iteration 2:
# Train dataset size= 101
# 1
# Iteration 3:
# Train dataset size= 102
# 2
# Iteration 4:
# Train dataset size= 103
# 3
# Iteration 5:
# Train dataset size= 104
# 4
# Iteration 6:
# Train dataset size= 105
# 5
# Iteration 7:
# Train dataset size= 106
# 6
# Iteration 8:
# Train dataset size= 107
# 7
# Iteration 9:
# Train dataset size= 108
# 8
# Iteration 10:
# Train dataset size= 109
# 9
# Iteration 11:
# Train dataset size= 110
# 10
# Iteration 12:
# Train dataset size= 111
# 11
# Iteration 13:
# Train dataset size= 112
# 12
# Iteration 14:
# Train dataset size= 113
# 13
# Iteration 15:
# Train dataset size= 114
# 14
# Iteration 16:
# Train dataset size= 115
# 15
# Iteration 17:
# Train dataset size= 116
# 16
# Iteration 18:
# Train dataset size= 117
# 17
# Iteration 19:
# Train dataset size= 118
# 18
# Iteration 20:
# Train dataset size= 119
# 19
# Iteration 21:
# Train dataset size= 120
# 20
# Iteration 22:
# Train dataset size= 121
# 21
# Iteration 23:
# Train dataset size= 122
# 22
# Iteration 24:
# Train dataset size= 123
# 23
# Iteration 25:
# Train dataset size= 124
# 24
# Iteration 26:
# Train dataset size= 125
# 25
# Iteration 27:
# Train dataset size= 126
# 26
# Iteration 28:
# Train dataset size= 127
# 27
# Iteration 29:
# Train dataset size= 128
# 28
# Iteration 30:
# Train dataset size= 129
# 29
# Iteration 31:
# Train dataset size= 130
# 30
# Iteration 32:
# Train dataset size= 131
# 31
# Iteration 33:
# Train dataset size= 132
# 32
# Iteration 34:
# Train dataset size= 133
# 33
# Iteration 35:
# Train dataset size= 134
# 34
# Iteration 36:
# Train dataset size= 135
# 35
# Iteration 37:
# Train dataset size= 136
# 36
# Iteration 38:
# Train dataset size= 137
# 37
# Iteration 39:
# Train dataset size= 138
# 38
# Iteration 40:
# Train dataset size= 139
# 39
# Iteration 41:
# Train dataset size= 140
# 40
# Iteration 42:
# Train dataset size= 141
# 41
# Iteration 43:
# Train dataset size= 142
# 42
# Iteration 44:
# Train dataset size= 143
# 43
# Iteration 45:
# Train dataset size= 144
# 44
# Iteration 46:
# Train dataset size= 145
# 45
# Iteration 47:
# Train dataset size= 146
# 46
# Iteration 48:
# Train dataset size= 147
# 47
# Iteration 49:
# Train dataset size= 148
# 48
# Iteration 50:
# Train dataset size= 149
# 49
# Iteration 51:
# Train dataset size= 150
# 50
# Iteration 52:
# Train dataset size= 151
# 51
# Iteration 53:
# Train dataset size= 152
# 52
# Iteration 54:
# Train dataset size= 153
# 53
# Iteration 55:
# Train dataset size= 154
# 54
# Iteration 56:
# Train dataset size= 155
# 55
# Iteration 57:
# Train dataset size= 156
# 56
# Iteration 58:
# Train dataset size= 157
# 57
# Iteration 59:
# Train dataset size= 158
# 58
# Iteration 60:
# Train dataset size= 159
# 59
# Iteration 61:
# Train dataset size= 160
# 60
# Iteration 62:
# Train dataset size= 161
# 61
# Iteration 63:
# Train dataset size= 162
# 62
# Iteration 64:
# Train dataset size= 163
# 63
# Iteration 65:
# Train dataset size= 164
# 64
# Iteration 66:
# Train dataset size= 165
# 65
# Iteration 67:
# Train dataset size= 166
# 66
# Iteration 68:
# Train dataset size= 167
# 67
# Iteration 69:
# Train dataset size= 168
# 68
# Iteration 70:
# Train dataset size= 169
# 69
# Iteration 71:
# Train dataset size= 170
# 70
# Iteration 72:
# Train dataset size= 171
# 71
# Iteration 73:
# Train dataset size= 172
# 72
# Iteration 74:
# Train dataset size= 173
# 73
# Iteration 75:
# Train dataset size= 174
# 74
# Iteration 76:
# Train dataset size= 175
# 75
# Iteration 77:
# Train dataset size= 176
# 76
# Iteration 78:
# Train dataset size= 177
# 77
# Iteration 79:
# Train dataset size= 178
# 78
# Iteration 80:
# Train dataset size= 179
# 79
# Iteration 81:
# Train dataset size= 180
# 80
# Iteration 82:
# Train dataset size= 181
# 81
# Iteration 83:
# Train dataset size= 182
# 82
# Iteration 84:
# Train dataset size= 183
# 83
# Iteration 85:
# Train dataset size= 184
# 84
# Iteration 86:
# Train dataset size= 185
# 85
# Iteration 87:
# Train dataset size= 186
# 86
# Iteration 88:
# Train dataset size= 187
# 87
# Iteration 89:
# Train dataset size= 188
# 88
# Iteration 90:
# Train dataset size= 189
# 89
# Iteration 91:
# Train dataset size= 190
# 90
# Iteration 92:
# Train dataset size= 191
# 91
# Iteration 93:
# Train dataset size= 192
# 92
# Iteration 94:
# Train dataset size= 193
# 93
# Iteration 95:
# Train dataset size= 194
# 94
# Iteration 96:
# Train dataset size= 195
# 95
# Iteration 97:
# Train dataset size= 196
# 96
# Iteration 98:
# Train dataset size= 197
# 97
# Iteration 99:
# Train dataset size= 198
# 98
# Iteration 100:
# Train dataset size= 199
# 99
# Iteration 101:
# Train dataset size= 200
# 0
# Iteration 102:
# Train dataset size= 201
# 1
# Iteration 103:
# Train dataset size= 202
# 2
# Iteration 104:
# Train dataset size= 203
# 3
# Iteration 105:
# Train dataset size= 204
# 4
# Iteration 106:
# Train dataset size= 205
# 5
# Iteration 107:
# Train dataset size= 206
# 6
# Iteration 108:
# Train dataset size= 207
# 7
# Iteration 109:
# Train dataset size= 208
# 8
# Iteration 110:
# Train dataset size= 209
# 9
# Iteration 111:
# Train dataset size= 210
# 10
# Iteration 112:
# Train dataset size= 211
# 11
# Iteration 113:
# Train dataset size= 212
# 12
# Iteration 114:
# Train dataset size= 213
# 13
# Iteration 115:
# Train dataset size= 214
# 14
# Iteration 116:
# Train dataset size= 215
# 15
# Iteration 117:
# Train dataset size= 216
# 16
# Iteration 118:
# Train dataset size= 217
# 17
# Iteration 119:
# Train dataset size= 218
# 18
# Iteration 120:
# Train dataset size= 219
# 19
# Iteration 121:
# Train dataset size= 220
# 20
# Iteration 122:
# Train dataset size= 221
# 21
# Iteration 123:
# Train dataset size= 222
# 22
# Iteration 124:
# Train dataset size= 223
# 23
# Iteration 125:
# Train dataset size= 224
# 24
# Iteration 126:
# Train dataset size= 225
# 25
# Iteration 127:
# Train dataset size= 226
# 26
# Iteration 128:
# Train dataset size= 227
# 27
# Iteration 129:
# Train dataset size= 228
# 28
# Iteration 130:
# Train dataset size= 229
# 29
# Iteration 131:
# Train dataset size= 230
# 30
# Iteration 132:
# Train dataset size= 231
# 31
# Iteration 133:
# Train dataset size= 232
# 32
# Iteration 134:
# Train dataset size= 233
# 33
# Iteration 135:
# Train dataset size= 234
# 34
# Iteration 136:
# Train dataset size= 235
# 35
# Iteration 137:
# Train dataset size= 236
# 36
# Iteration 138:
# Train dataset size= 237
# 37
# Iteration 139:
# Train dataset size= 238
# 38
# Iteration 140:
# Train dataset size= 239
# 39
# Iteration 141:
# Train dataset size= 240
# 40
# Iteration 142:
# Train dataset size= 241
# 41
# Iteration 143:
# Train dataset size= 242
# 42
# Iteration 144:
# Train dataset size= 243
# 43
# Iteration 145:
# Train dataset size= 244
# 44
# Iteration 146:
# Train dataset size= 245
# 45
# Iteration 147:
# Train dataset size= 246
# 46
# Iteration 148:
# Train dataset size= 247
# 47
# Iteration 149:
# Train dataset size= 248
# 48
# Iteration 150:
# Train dataset size= 249
# 49
# Iteration 151:
# Train dataset size= 250
# 50
# Iteration 152:
# Train dataset size= 251
# 51
# Iteration 153:
# Train dataset size= 252
# 52
# Iteration 154:
# Train dataset size= 253
# 53
# Iteration 155:
# Train dataset size= 254
# 54
# Iteration 156:
# Train dataset size= 255
# 55
# Iteration 157:
# Train dataset size= 256
# 56
# Iteration 158:
# Train dataset size= 257
# 57
# Iteration 159:
# Train dataset size= 258
# 58
# Iteration 160:
# Train dataset size= 259
# 59
# Iteration 161:
# Train dataset size= 260
# 60
# Iteration 162:
# Train dataset size= 261
# 61
# Iteration 163:
# Train dataset size= 262
# 62
# Iteration 164:
# Train dataset size= 263
# 63
# Iteration 165:
# Train dataset size= 264
# 64
# Iteration 166:
# Train dataset size= 265
# 65
# Iteration 167:
# Train dataset size= 266
# 66
# Iteration 168:
# Train dataset size= 267
# 67
# Iteration 169:
# Train dataset size= 268
# 68
# Iteration 170:
# Train dataset size= 269
# 69
# Iteration 171:
# Train dataset size= 270
# 70
# Iteration 172:
# Train dataset size= 271
# 71
# Iteration 173:
# Train dataset size= 272
# 72
# Iteration 174:
# Train dataset size= 273
# 73
# Iteration 175:
# Train dataset size= 274
# 74
# Iteration 176:
# Train dataset size= 275
# 75
# Iteration 177:
# Train dataset size= 276
# 76
# Iteration 178:
# Train dataset size= 277
# 77
# Iteration 179:
# Train dataset size= 278
# 78
# Iteration 180:
# Train dataset size= 279
# 79
# Iteration 181:
# Train dataset size= 280
# 80
# Iteration 182:
# Train dataset size= 281
# 81
# Iteration 183:
# Train dataset size= 282
# 82
# Iteration 184:
# Train dataset size= 283
# 83
# Iteration 185:
# Train dataset size= 284
# 84
# Iteration 186:
# Train dataset size= 285
# 85
# Iteration 187:
# Train dataset size= 286
# 86
# Iteration 188:
# Train dataset size= 287
# 87
# Iteration 189:
# Train dataset size= 288
# 88
# Iteration 190:
# Train dataset size= 289
# 89
# Iteration 191:
# Train dataset size= 290
# 90
# Iteration 192:
# Train dataset size= 291
# 91
# Iteration 193:
# Train dataset size= 292
# 92
# Iteration 194:
# Train dataset size= 293
# 93
# Iteration 195:
# Train dataset size= 294
# 94
# Iteration 196:
# Train dataset size= 295
# 95
# Iteration 197:
# Train dataset size= 296
# 96
# Iteration 198:
# Train dataset size= 297
# 97
# Iteration 199:
# Train dataset size= 298
# 98
# Iteration 200:
# Train dataset size= 299
# 99
# Iteration 201:
# Train dataset size= 300
# 0
# Iteration 202:
# Train dataset size= 301
# 1
# Iteration 203:
# Train dataset size= 302
# 2
# Iteration 204:
# Train dataset size= 303
# 3
# Iteration 205:
# Train dataset size= 304
# 4
# Iteration 206:
# Train dataset size= 305
# 5
# Iteration 207:
# Train dataset size= 306
# 6
# Iteration 208:
# Train dataset size= 307
# 7
# Iteration 209:
# Train dataset size= 308
# 8
# Iteration 210:
# Train dataset size= 309
# 9
# Iteration 211:
# Train dataset size= 310
# 10
# Iteration 212:
# Train dataset size= 311
# 11
# Iteration 213:
# Train dataset size= 312
# 12
# Iteration 214:
# Train dataset size= 313
# 13
# Iteration 215:
# Train dataset size= 314
# 14
# Iteration 216:
# Train dataset size= 315
# 15
# Iteration 217:
# Train dataset size= 316
# 16
# Iteration 218:
# Train dataset size= 317
# 17
# Iteration 219:
# Train dataset size= 318
# 18
# Iteration 220:
# Train dataset size= 319
# 19
# Iteration 221:
# Train dataset size= 320
# 20
# Iteration 222:
# Train dataset size= 321
# 21
# Iteration 223:
# Train dataset size= 322
# 22
# Iteration 224:
# Train dataset size= 323
# 23
# Iteration 225:
# Train dataset size= 324
# 24
# Iteration 226:
# Train dataset size= 325
# 25
# Iteration 227:
# Train dataset size= 326
# 26
# Iteration 228:
# Train dataset size= 327
# 27
# Iteration 229:
# Train dataset size= 328
# 28
# Iteration 230:
# Train dataset size= 329
# 29
# Iteration 231:
# Train dataset size= 330
# 30
# Iteration 232:
# Train dataset size= 331
# 31
# Iteration 233:
# Train dataset size= 332
# 32
# Iteration 234:
# Train dataset size= 333
# 33
# Iteration 235:
# Train dataset size= 334
# 34
# Iteration 236:
# Train dataset size= 335
# 35
# Iteration 237:
# Train dataset size= 336
# 36
# Iteration 238:
# Train dataset size= 337
# 37
# Iteration 239:
# Train dataset size= 338
# 38
# Iteration 240:
# Train dataset size= 339
# 39
# Iteration 241:
# Train dataset size= 340
# 40
# Iteration 242:
# Train dataset size= 341
# 41
# Iteration 243:
# Train dataset size= 342
# 42
# Iteration 244:
# Train dataset size= 343
# 43
# Iteration 245:
# Train dataset size= 344
# 44
# Iteration 246:
# Train dataset size= 345
# 45
# Iteration 247:
# Train dataset size= 346
# 46
# Iteration 248:
# Train dataset size= 347
# 47
# Iteration 249:
# Train dataset size= 348
# 48
# Iteration 250:
# Train dataset size= 349
# 49
# Iteration 251:
# Train dataset size= 350
# 50
# Iteration 252:
# Train dataset size= 351
# 51
# Iteration 253:
# Train dataset size= 352
# 52
# Iteration 254:
# Train dataset size= 353
# 53
# Iteration 255:
# Train dataset size= 354
# 54
# Iteration 256:
# Train dataset size= 355
# 55
# Iteration 257:
# Train dataset size= 356
# 56
# Iteration 258:
# Train dataset size= 357
# 57
# Iteration 259:
# Train dataset size= 358
# 58
# Iteration 260:
# Train dataset size= 359
# 59
# Iteration 261:
# Train dataset size= 360
# 60
# Iteration 262:
# Train dataset size= 361
# 61
# Iteration 263:
# Train dataset size= 362
# 62
# Iteration 264:
# Train dataset size= 363
# 63
# Iteration 265:
# Train dataset size= 364
# 64
# Iteration 266:
# Train dataset size= 365
# 65
# Iteration 267:
# Train dataset size= 366
# 66
# Iteration 268:
# Train dataset size= 367
# 67
# Iteration 269:
# Train dataset size= 368
# 68
# Iteration 270:
# Train dataset size= 369
# 69
# Iteration 271:
# Train dataset size= 370
# 70
# Iteration 272:
# Train dataset size= 371
# 71
# Iteration 273:
# Train dataset size= 372
# 72
# Iteration 274:
# Train dataset size= 373
# 73
# Iteration 275:
# Train dataset size= 374
# 74
# Iteration 276:
# Train dataset size= 375
# 75
# Iteration 277:
# Train dataset size= 376
# 76
# Iteration 278:
# Train dataset size= 377
# 77
# Iteration 279:
# Train dataset size= 378
# 78
# Iteration 280:
# Train dataset size= 379
# 79
# Iteration 281:
# Train dataset size= 380
# 80
# Iteration 282:
# Train dataset size= 381
# 81
# Iteration 283:
# Train dataset size= 382
# 82
# Iteration 284:
# Train dataset size= 383
# 83
# Iteration 285:
# Train dataset size= 384
# 84
# Iteration 286:
# Train dataset size= 385
# 85
# Iteration 287:
# Train dataset size= 386
# 86
# Iteration 288:
# Train dataset size= 387
# 87
# Iteration 289:
# Train dataset size= 388
# 88
# Iteration 290:
# Train dataset size= 389
# 89
# Iteration 291:
# Train dataset size= 390
# 90
# Iteration 292:
# Train dataset size= 391
# 91
# Iteration 293:
# Train dataset size= 392
# 92
# Iteration 294:
# Train dataset size= 393
# 93
# Iteration 295:
# Train dataset size= 394
# 94
# Iteration 296:
# Train dataset size= 395
# 95
# Iteration 297:
# Train dataset size= 396
# 96
# Iteration 298:
# Train dataset size= 397
# 97
# Iteration 299:
# Train dataset size= 398
# 98
# Iteration 300:
# Train dataset size= 399
# 99
# Iteration 301:
# Train dataset size= 400
# 0
# Iteration 302:
# Train dataset size= 401
# 1
# Iteration 303:
# Train dataset size= 402
# 2
# Iteration 304:
# Train dataset size= 403
# 3
# Iteration 305:
# Train dataset size= 404
# 4
# Iteration 306:
# Train dataset size= 405
# 5
# Iteration 307:
# Train dataset size= 406
# 6
# Iteration 308:
# Train dataset size= 407
# 7
# Iteration 309:
# Train dataset size= 408
# 8

# %% [markdown]
# # Plots

# %%
np.savez('train_dataset_KNN', x_train=x_train_classifer, y_train=y_train_classifer)

# %%
plt.plot(hist_clf_train_f1)
plt.xlabel("Iteration")
plt.ylabel("F1-score")
plt.title("Classifier Train F1-score")

# %%
plt.plot(hist_clf_test_f1)
plt.xlabel("Iteration")
plt.ylabel("F1-score")
plt.title("Classifier Test F1-score")
# plt.yscale('log')
plt.show()
