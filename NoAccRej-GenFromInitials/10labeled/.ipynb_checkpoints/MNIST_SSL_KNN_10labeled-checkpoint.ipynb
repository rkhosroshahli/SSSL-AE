# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from sklearn.metrics import f1_score

import matplotlib.pyplot as plt

# %%
# Model / data parameters
num_classes = 10
input_shape = (28, 28, 1)
ndim=28

# Load the data and split it between train and test sets
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

# Scale images to the [0, 1] range
x_train = x_train.astype("float32") / 255
x_test = x_test.astype("float32") / 255
# Make sure images have shape (28, 28, 1)
x_train = np.expand_dims(x_train, -1)
x_test = np.expand_dims(x_test, -1)
print("x_train shape:", x_train.shape)
print(x_train.shape[0], "train samples")
print(x_test.shape[0], "test samples")


# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples

# %%
fashion_mnist = tf.keras.datasets.fashion_mnist

(X_train_fs, y_train_fs), (X_test_fs, y_test_fs) = fashion_mnist.load_data()
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
fig, axarr = plt.subplots(1,6, figsize=(10,8))
for i in range(len(axarr)-3):
    axarr[i].imshow(x_train[i].reshape(ndim,ndim), cmap='gist_gray')
    axarr[i].set_title(f"Label={y_train[i].argmax()}")
    axarr[i].yaxis.set_visible(False)
    axarr[i].xaxis.set_visible(False)
    
for i in range(len(axarr)-3, len(axarr)):
    axarr[i].imshow(X_train_fs[i].reshape(ndim,ndim), cmap='gist_gray')
    axarr[i].set_title(f"Label={class_names[y_train_fs[i]]}")
    axarr[i].yaxis.set_visible(False)
    axarr[i].xaxis.set_visible(False)

# %%
def unison_shuffled_copies(a, b):
    assert len(a) == len(b)
    p = np.random.permutation(len(a))
    return a[p], b[p]

# %%
from sklearn.neighbors import KNeighborsClassifier
def run_classifier(x_train_classifer, y_train_classifer, x_test_classifer, y_test_classifer):
        clf = KNeighborsClassifier(10)
        clf.fit(x_train_classifer.reshape((len(x_train_classifer), ndim*ndim)), y_train_classifer)

        y_pred = clf.predict(x_train_classifer.reshape((len(x_train_classifer), ndim*ndim)))
        clf_train_f1 = f1_score(y_train_classifer, y_pred, average='macro')
        y_pred = clf.predict(x_test_classifer.reshape((len(x_test_classifer), ndim*ndim)))
        clf_test_f1 = f1_score(y_test_classifer, y_pred, average='macro')

        print(f"Train F1-score= {(clf_train_f1):.3e}")
        print(f"Test F1-score= {(clf_test_f1):.3e}")
        
        return clf_train_f1, clf_test_f1

# %%
step=1
mean=0
std=0.05
noise_factor=1.0

# %%
autoencoder=keras.models.load_model('mnist_50epoch_128batch_50000train_autoencoder.h5')
encoder=keras.models.load_model('mnist_50epoch_128batch_50000train_encoder.h5')
decoder=keras.models.load_model('mnist_50epoch_128batch_50000train_decoder.h5')
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
img_per_class=1

labeled_train_data_counter=np.zeros(10)
labeled_train_data_indices=np.ones((10,img_per_class))*-1
for i, y in enumerate(y_train[50000:]):
    if labeled_train_data_counter.sum() == img_per_class*10:
        break
    y_arg = y.argmax()
    counter= int(labeled_train_data_counter[y_arg])
    if counter >= img_per_class:
        continue
    if labeled_train_data_indices[y_arg, counter] == -1:
        labeled_train_data_counter[y_arg] +=1
        labeled_train_data_indices[y_arg, counter] = i
        
labeled_train_data_indices=labeled_train_data_indices.astype(int)+50000

indices=labeled_train_data_indices.flatten('F')
x_train_classifer=x_train[indices].copy()
y_train_classifer=y_train[indices].copy().argmax(axis=1)

x_test_classifer=x_test.copy()
y_test_classifer=y_test.copy().argmax(axis=1)

print(x_train_classifer.shape)

hist_clf_train_f1, hist_clf_test_f1=[], []

clf_train_f1, clf_test_f1=run_classifier(x_train_classifer, y_train_classifer,
                                         x_test_classifer, y_test_classifer)
hist_clf_train_f1.append(clf_train_f1)
hist_clf_test_f1.append(clf_test_f1)
# Out:
# (10, 28, 28, 1)
# Train F1-score= 1.818e-02
# Test F1-score= 1.785e-02

# %%
labeled_train_data_indices
# Out:
# array([[50018],
#        [50016],
#        [50011],
#        [50000],
#        [50005],
#        [50006],
#        [50002],
#        [50021],
#        [50001],
#        [50003]])

# %%
mse=keras.losses.MeanSquaredError()

# %%
def plot_orig_recon_imgs(labeled_img, noised_img, iteration, y_true):
    fig, axarr = plt.subplots(1,2)
    axarr[0].imshow(labeled_img, cmap='gist_gray')
    axarr[0].set_title("Original Image")
    axarr[0].yaxis.set_visible(False)
    axarr[0].xaxis.set_visible(False)
    axarr[1].imshow(noised_img[0], cmap='gist_gray')
    axarr[1].set_title("Reconstructed Image")
    axarr[1].yaxis.set_visible(False)
    axarr[1].xaxis.set_visible(False)
    fig.suptitle(f"Iteration {iteration}, Image Label: {y_true}")
    fig.savefig(f"plots/iteration{iteration}")
    plt.close()
    # plt.show()

# %%
idx=0
iteration=0

# %%
# x_unseen=x_train[50000:].copy()
# y_unseen=y_train[50000:].copy().argmax(axis=1)
rejected_counter=0
accepted_counter=0

while iteration < 10000:

    iteration+=1
    print(f"Iteration {iteration}:")
    
    train_size=x_train_classifer.shape[0]
    print("Train dataset size=", train_size)
    
    # random_idx=np.random.choice(10*img_per_class, 1)[0]
    idx=idx%(10*img_per_class)
    random_idx=idx
    print(random_idx)
    labeled_img = x_train_classifer[random_idx]
    encoded_data = encoder.predict(np.array([labeled_img]), verbose=0)
    noise_data = noise_factor * np.random.normal(mean, std, size=encoded_data.shape)
    perturbed_data = noise_data+encoded_data
    noised_img = decoder.predict(perturbed_data, verbose=0)
        
    plot_orig_recon_imgs(labeled_img, noised_img, iteration, y_train_classifer[random_idx])
    
    x_train_classifer = np.concatenate([x_train_classifer, noised_img], axis=0)
    y_train_classifer = np.concatenate([y_train_classifer, [y_train_classifer[random_idx]]])
    
    if iteration % 1000==0:
        clf_train_f1, clf_test_f1=run_classifier(x_train_classifer, y_train_classifer,
                                                 x_test_classifer, y_test_classifer)
        hist_clf_train_f1.append(clf_train_f1)
        hist_clf_test_f1.append(clf_test_f1)

    idx+=1
# Out:
# Iteration 1:
# Train dataset size= 10
# 0
# Iteration 2:
# Train dataset size= 11
# 1
# Iteration 3:
# Train dataset size= 12
# 2
# Iteration 4:
# Train dataset size= 13
# 3
# Iteration 5:
# Train dataset size= 14
# 4
# Iteration 6:
# Train dataset size= 15
# 5
# Iteration 7:
# Train dataset size= 16
# 6
# Iteration 8:
# Train dataset size= 17
# 7
# Iteration 9:
# Train dataset size= 18
# 8
# Iteration 10:
# Train dataset size= 19
# 9
# Iteration 11:
# Train dataset size= 20
# 0
# Iteration 12:
# Train dataset size= 21
# 1
# Iteration 13:
# Train dataset size= 22
# 2
# Iteration 14:
# Train dataset size= 23
# 3
# Iteration 15:
# Train dataset size= 24
# 4
# Iteration 16:
# Train dataset size= 25
# 5
# Iteration 17:
# Train dataset size= 26
# 6
# Iteration 18:
# Train dataset size= 27
# 7
# Iteration 19:
# Train dataset size= 28
# 8
# Iteration 20:
# Train dataset size= 29
# 9
# Iteration 21:
# Train dataset size= 30
# 0
# Iteration 22:
# Train dataset size= 31
# 1
# Iteration 23:
# Train dataset size= 32
# 2
# Iteration 24:
# Train dataset size= 33
# 3
# Iteration 25:
# Train dataset size= 34
# 4
# Iteration 26:
# Train dataset size= 35
# 5
# Iteration 27:
# Train dataset size= 36
# 6
# Iteration 28:
# Train dataset size= 37
# 7
# Iteration 29:
# Train dataset size= 38
# 8
# Iteration 30:
# Train dataset size= 39
# 9
# Iteration 31:
# Train dataset size= 40
# 0
# Iteration 32:
# Train dataset size= 41
# 1
# Iteration 33:
# Train dataset size= 42
# 2
# Iteration 34:
# Train dataset size= 43
# 3
# Iteration 35:
# Train dataset size= 44
# 4
# Iteration 36:
# Train dataset size= 45
# 5
# Iteration 37:
# Train dataset size= 46
# 6
# Iteration 38:
# Train dataset size= 47
# 7
# Iteration 39:
# Train dataset size= 48
# 8
# Iteration 40:
# Train dataset size= 49
# 9
# Iteration 41:
# Train dataset size= 50
# 0
# Iteration 42:
# Train dataset size= 51
# 1
# Iteration 43:
# Train dataset size= 52
# 2
# Iteration 44:
# Train dataset size= 53
# 3
# Iteration 45:
# Train dataset size= 54
# 4
# Iteration 46:
# Train dataset size= 55
# 5
# Iteration 47:
# Train dataset size= 56
# 6
# Iteration 48:
# Train dataset size= 57
# 7
# Iteration 49:
# Train dataset size= 58
# 8
# Iteration 50:
# Train dataset size= 59
# 9
# Iteration 51:
# Train dataset size= 60
# 0
# Iteration 52:
# Train dataset size= 61
# 1
# Iteration 53:
# Train dataset size= 62
# 2
# Iteration 54:
# Train dataset size= 63
# 3
# Iteration 55:
# Train dataset size= 64
# 4
# Iteration 56:
# Train dataset size= 65
# 5
# Iteration 57:
# Train dataset size= 66
# 6
# Iteration 58:
# Train dataset size= 67
# 7
# Iteration 59:
# Train dataset size= 68
# 8
# Iteration 60:
# Train dataset size= 69
# 9
# Iteration 61:
# Train dataset size= 70
# 0
# Iteration 62:
# Train dataset size= 71
# 1
# Iteration 63:
# Train dataset size= 72
# 2
# Iteration 64:
# Train dataset size= 73
# 3
# Iteration 65:
# Train dataset size= 74
# 4
# Iteration 66:
# Train dataset size= 75
# 5
# Iteration 67:
# Train dataset size= 76
# 6
# Iteration 68:
# Train dataset size= 77
# 7
# Iteration 69:
# Train dataset size= 78
# 8
# Iteration 70:
# Train dataset size= 79
# 9
# Iteration 71:
# Train dataset size= 80
# 0
# Iteration 72:
# Train dataset size= 81
# 1
# Iteration 73:
# Train dataset size= 82
# 2
# Iteration 74:
# Train dataset size= 83
# 3
# Iteration 75:
# Train dataset size= 84
# 4
# Iteration 76:
# Train dataset size= 85
# 5
# Iteration 77:
# Train dataset size= 86
# 6
# Iteration 78:
# Train dataset size= 87
# 7
# Iteration 79:
# Train dataset size= 88
# 8
# Iteration 80:
# Train dataset size= 89
# 9
# Iteration 81:
# Train dataset size= 90
# 0
# Iteration 82:
# Train dataset size= 91
# 1
# Iteration 83:
# Train dataset size= 92
# 2
# Iteration 84:
# Train dataset size= 93
# 3
# Iteration 85:
# Train dataset size= 94
# 4
# Iteration 86:
# Train dataset size= 95
# 5
# Iteration 87:
# Train dataset size= 96
# 6
# Iteration 88:
# Train dataset size= 97
# 7
# Iteration 89:
# Train dataset size= 98
# 8
# Iteration 90:
# Train dataset size= 99
# 9
# Iteration 91:
# Train dataset size= 100
# 0
# Iteration 92:
# Train dataset size= 101
# 1
# Iteration 93:
# Train dataset size= 102
# 2
# Iteration 94:
# Train dataset size= 103
# 3
# Iteration 95:
# Train dataset size= 104
# 4
# Iteration 96:
# Train dataset size= 105
# 5
# Iteration 97:
# Train dataset size= 106
# 6
# Iteration 98:
# Train dataset size= 107
# 7
# Iteration 99:
# Train dataset size= 108
# 8
# Iteration 100:
# Train dataset size= 109
# 9
# Iteration 101:
# Train dataset size= 110
# 0
# Iteration 102:
# Train dataset size= 111
# 1
# Iteration 103:
# Train dataset size= 112
# 2
# Iteration 104:
# Train dataset size= 113
# 3
# Iteration 105:
# Train dataset size= 114
# 4
# Iteration 106:
# Train dataset size= 115
# 5
# Iteration 107:
# Train dataset size= 116
# 6
# Iteration 108:
# Train dataset size= 117
# 7
# Iteration 109:
# Train dataset size= 118
# 8
# Iteration 110:
# Train dataset size= 119
# 9
# Iteration 111:
# Train dataset size= 120
# 0
# Iteration 112:
# Train dataset size= 121
# 1
# Iteration 113:
# Train dataset size= 122
# 2
# Iteration 114:
# Train dataset size= 123
# 3
# Iteration 115:
# Train dataset size= 124
# 4
# Iteration 116:
# Train dataset size= 125
# 5
# Iteration 117:
# Train dataset size= 126
# 6
# Iteration 118:
# Train dataset size= 127
# 7
# Iteration 119:
# Train dataset size= 128
# 8
# Iteration 120:
# Train dataset size= 129
# 9
# Iteration 121:
# Train dataset size= 130
# 0
# Iteration 122:
# Train dataset size= 131
# 1
# Iteration 123:
# Train dataset size= 132
# 2
# Iteration 124:
# Train dataset size= 133
# 3
# Iteration 125:
# Train dataset size= 134
# 4
# Iteration 126:
# Train dataset size= 135
# 5
# Iteration 127:
# Train dataset size= 136
# 6
# Iteration 128:
# Train dataset size= 137
# 7
# Iteration 129:
# Train dataset size= 138
# 8
# Iteration 130:
# Train dataset size= 139
# 9
# Iteration 131:
# Train dataset size= 140
# 0
# Iteration 132:
# Train dataset size= 141
# 1
# Iteration 133:
# Train dataset size= 142
# 2
# Iteration 134:
# Train dataset size= 143
# 3
# Iteration 135:
# Train dataset size= 144
# 4
# Iteration 136:
# Train dataset size= 145
# 5
# Iteration 137:
# Train dataset size= 146
# 6
# Iteration 138:
# Train dataset size= 147
# 7
# Iteration 139:
# Train dataset size= 148
# 8
# Iteration 140:
# Train dataset size= 149
# 9
# Iteration 141:
# Train dataset size= 150
# 0
# Iteration 142:
# Train dataset size= 151
# 1
# Iteration 143:
# Train dataset size= 152
# 2
# Iteration 144:
# Train dataset size= 153
# 3
# Iteration 145:
# Train dataset size= 154
# 4
# Iteration 146:
# Train dataset size= 155
# 5
# Iteration 147:
# Train dataset size= 156
# 6
# Iteration 148:
# Train dataset size= 157
# 7
# Iteration 149:
# Train dataset size= 158
# 8
# Iteration 150:
# Train dataset size= 159
# 9
# Iteration 151:
# Train dataset size= 160
# 0
# Iteration 152:
# Train dataset size= 161
# 1
# Iteration 153:
# Train dataset size= 162
# 2
# Iteration 154:
# Train dataset size= 163
# 3
# Iteration 155:
# Train dataset size= 164
# 4
# Iteration 156:
# Train dataset size= 165
# 5
# Iteration 157:
# Train dataset size= 166
# 6
# Iteration 158:
# Train dataset size= 167
# 7
# Iteration 159:
# Train dataset size= 168
# 8
# Iteration 160:
# Train dataset size= 169
# 9
# Iteration 161:
# Train dataset size= 170
# 0
# Iteration 162:
# Train dataset size= 171
# 1
# Iteration 163:
# Train dataset size= 172
# 2
# Iteration 164:
# Train dataset size= 173
# 3
# Iteration 165:
# Train dataset size= 174
# 4
# Iteration 166:
# Train dataset size= 175
# 5
# Iteration 167:
# Train dataset size= 176
# 6
# Iteration 168:
# Train dataset size= 177
# 7
# Iteration 169:
# Train dataset size= 178
# 8
# Iteration 170:
# Train dataset size= 179
# 9
# Iteration 171:
# Train dataset size= 180
# 0
# Iteration 172:
# Train dataset size= 181
# 1
# Iteration 173:
# Train dataset size= 182
# 2
# Iteration 174:
# Train dataset size= 183
# 3
# Iteration 175:
# Train dataset size= 184
# 4
# Iteration 176:
# Train dataset size= 185
# 5
# Iteration 177:
# Train dataset size= 186
# 6
# Iteration 178:
# Train dataset size= 187
# 7
# Iteration 179:
# Train dataset size= 188
# 8
# Iteration 180:
# Train dataset size= 189
# 9
# Iteration 181:
# Train dataset size= 190
# 0
# Iteration 182:
# Train dataset size= 191
# 1
# Iteration 183:
# Train dataset size= 192
# 2
# Iteration 184:
# Train dataset size= 193
# 3
# Iteration 185:
# Train dataset size= 194
# 4
# Iteration 186:
# Train dataset size= 195
# 5
# Iteration 187:
# Train dataset size= 196
# 6
# Iteration 188:
# Train dataset size= 197
# 7
# Iteration 189:
# Train dataset size= 198
# 8
# Iteration 190:
# Train dataset size= 199
# 9
# Iteration 191:
# Train dataset size= 200
# 0
# Iteration 192:
# Train dataset size= 201
# 1
# Iteration 193:
# Train dataset size= 202
# 2
# Iteration 194:
# Train dataset size= 203
# 3
# Iteration 195:
# Train dataset size= 204
# 4
# Iteration 196:
# Train dataset size= 205
# 5
# Iteration 197:
# Train dataset size= 206
# 6
# Iteration 198:
# Train dataset size= 207
# 7
# Iteration 199:
# Train dataset size= 208
# 8
# Iteration 200:
# Train dataset size= 209
# 9
# Iteration 201:
# Train dataset size= 210
# 0
# Iteration 202:
# Train dataset size= 211
# 1
# Iteration 203:
# Train dataset size= 212
# 2
# Iteration 204:
# Train dataset size= 213
# 3
# Iteration 205:
# Train dataset size= 214
# 4
# Iteration 206:
# Train dataset size= 215
# 5
# Iteration 207:
# Train dataset size= 216
# 6
# Iteration 208:
# Train dataset size= 217
# 7
# Iteration 209:
# Train dataset size= 218
# 8
# Iteration 210:
# Train dataset size= 219
# 9
# Iteration 211:
# Train dataset size= 220
# 0
# Iteration 212:
# Train dataset size= 221
# 1
# Iteration 213:
# Train dataset size= 222
# 2
# Iteration 214:
# Train dataset size= 223
# 3
# Iteration 215:
# Train dataset size= 224
# 4
# Iteration 216:
# Train dataset size= 225
# 5
# Iteration 217:
# Train dataset size= 226
# 6
# Iteration 218:
# Train dataset size= 227
# 7
# Iteration 219:
# Train dataset size= 228
# 8
# Iteration 220:
# Train dataset size= 229
# 9
# Iteration 221:
# Train dataset size= 230
# 0
# Iteration 222:
# Train dataset size= 231
# 1
# Iteration 223:
# Train dataset size= 232
# 2
# Iteration 224:
# Train dataset size= 233
# 3
# Iteration 225:
# Train dataset size= 234
# 4
# Iteration 226:
# Train dataset size= 235
# 5
# Iteration 227:
# Train dataset size= 236
# 6
# Iteration 228:
# Train dataset size= 237
# 7
# Iteration 229:
# Train dataset size= 238
# 8
# Iteration 230:
# Train dataset size= 239
# 9
# Iteration 231:
# Train dataset size= 240
# 0
# Iteration 232:
# Train dataset size= 241
# 1
# Iteration 233:
# Train dataset size= 242
# 2
# Iteration 234:
# Train dataset size= 243
# 3
# Iteration 235:
# Train dataset size= 244
# 4
# Iteration 236:
# Train dataset size= 245
# 5
# Iteration 237:
# Train dataset size= 246
# 6
# Iteration 238:
# Train dataset size= 247
# 7
# Iteration 239:
# Train dataset size= 248
# 8
# Iteration 240:
# Train dataset size= 249
# 9
# Iteration 241:
# Train dataset size= 250
# 0
# Iteration 242:
# Train dataset size= 251
# 1
# Iteration 243:
# Train dataset size= 252
# 2
# Iteration 244:
# Train dataset size= 253
# 3
# Iteration 245:
# Train dataset size= 254
# 4
# Iteration 246:
# Train dataset size= 255
# 5
# Iteration 247:
# Train dataset size= 256
# 6
# Iteration 248:
# Train dataset size= 257
# 7
# Iteration 249:
# Train dataset size= 258
# 8
# Iteration 250:
# Train dataset size= 259
# 9
# Iteration 251:
# Train dataset size= 260
# 0
# Iteration 252:
# Train dataset size= 261
# 1
# Iteration 253:
# Train dataset size= 262
# 2
# Iteration 254:
# Train dataset size= 263
# 3
# Iteration 255:
# Train dataset size= 264
# 4
# Iteration 256:
# Train dataset size= 265
# 5
# Iteration 257:
# Train dataset size= 266
# 6
# Iteration 258:
# Train dataset size= 267
# 7
# Iteration 259:
# Train dataset size= 268
# 8
# Iteration 260:
# Train dataset size= 269
# 9
# Iteration 261:
# Train dataset size= 270
# 0
# Iteration 262:
# Train dataset size= 271
# 1
# Iteration 263:
# Train dataset size= 272
# 2
# Iteration 264:
# Train dataset size= 273
# 3
# Iteration 265:
# Train dataset size= 274
# 4
# Iteration 266:
# Train dataset size= 275
# 5
# Iteration 267:
# Train dataset size= 276
# 6
# Iteration 268:
# Train dataset size= 277
# 7
# Iteration 269:
# Train dataset size= 278
# 8
# Iteration 270:
# Train dataset size= 279
# 9
# Iteration 271:
# Train dataset size= 280
# 0
# Iteration 272:
# Train dataset size= 281
# 1
# Iteration 273:
# Train dataset size= 282
# 2
# Iteration 274:
# Train dataset size= 283
# 3
# Iteration 275:
# Train dataset size= 284
# 4
# Iteration 276:
# Train dataset size= 285
# 5
# Iteration 277:
# Train dataset size= 286
# 6
# Iteration 278:
# Train dataset size= 287
# 7
# Iteration 279:
# Train dataset size= 288
# 8
# Iteration 280:
# Train dataset size= 289
# 9
# Iteration 281:
# Train dataset size= 290
# 0
# Iteration 282:
# Train dataset size= 291
# 1
# Iteration 283:
# Train dataset size= 292
# 2
# Iteration 284:
# Train dataset size= 293
# 3
# Iteration 285:
# Train dataset size= 294
# 4
# Iteration 286:
# Train dataset size= 295
# 5
# Iteration 287:
# Train dataset size= 296
# 6
# Iteration 288:
# Train dataset size= 297
# 7
# Iteration 289:
# Train dataset size= 298
# 8
# Iteration 290:
# Train dataset size= 299
# 9
# Iteration 291:
# Train dataset size= 300
# 0
# Iteration 292:
# Train dataset size= 301
# 1
# Iteration 293:
# Train dataset size= 302
# 2
# Iteration 294:
# Train dataset size= 303
# 3
# Iteration 295:
# Train dataset size= 304
# 4
# Iteration 296:
# Train dataset size= 305
# 5
# Iteration 297:
# Train dataset size= 306
# 6
# Iteration 298:
# Train dataset size= 307
# 7
# Iteration 299:
# Train dataset size= 308
# 8
# Iteration 300:
# Train dataset size= 309
# 9
# Iteration 301:
# Train dataset size= 310
# 0
# Iteration 302:
# Train dataset size= 311
# 1
# Iteration 303:
# Train dataset size= 312
# 2
# Iteration 304:
# Train dataset size= 313
# 3
# Iteration 305:
# Train dataset size= 314
# 4
# Iteration 306:
# Train dataset size= 315
# 5
# Iteration 307:
# Train dataset size= 316
# 6
# Iteration 308:
# Train dataset size= 317
# 7
# Iteration 309:
# Train dataset size= 318
# 8
# Iteration 310:
# Train dataset size= 319
# 9
# Iteration 311:
# Train dataset size= 320
# 0
# Iteration 312:
# Train dataset size= 321
# 1
# Iteration 313:
# Train dataset size= 322
# 2
# Iteration 314:
# Train dataset size= 323
# 3
# Iteration 315:
# Train dataset size= 324
# 4
# Iteration 316:
# Train dataset size= 325
# 5
# Iteration 317:
# Train dataset size= 326
# 6
# Iteration 318:
# Train dataset size= 327
# 7
# Iteration 319:
# Train dataset size= 328
# 8
# Iteration 320:
# Train dataset size= 329
# 9
# Iteration 321:
# Train dataset size= 330
# 0
# Iteration 322:
# Train dataset size= 331
# 1
# Iteration 323:
# Train dataset size= 332
# 2
# Iteration 324:
# Train dataset size= 333
# 3
# Iteration 325:
# Train dataset size= 334
# 4
# Iteration 326:
# Train dataset size= 335
# 5
# Iteration 327:
# Train dataset size= 336
# 6
# Iteration 328:
# Train dataset size= 337
# 7
# Iteration 329:
# Train dataset size= 338
# 8
# Iteration 330:
# Train dataset size= 339
# 9
# Iteration 331:
# Train dataset size= 340
# 0
# Iteration 332:
# Train dataset size= 341
# 1
# Iteration 333:
# Train dataset size= 342
# 2
# Iteration 334:
# Train dataset size= 343
# 3
# Iteration 335:
# Train dataset size= 344
# 4
# Iteration 336:
# Train dataset size= 345
# 5
# Iteration 337:
# Train dataset size= 346
# 6
# Iteration 338:
# Train dataset size= 347
# 7
# Iteration 339:
# Train dataset size= 348
# 8
# Iteration 340:
# Train dataset size= 349
# 9
# Iteration 341:
# Train dataset size= 350
# 0
# Iteration 342:
# Train dataset size= 351
# 1
# Iteration 343:
# Train dataset size= 352
# 2
# Iteration 344:
# Train dataset size= 353
# 3
# Iteration 345:
# Train dataset size= 354
# 4
# Iteration 346:
# Train dataset size= 355
# 5
# Iteration 347:
# Train dataset size= 356
# 6
# Iteration 348:
# Train dataset size= 357
# 7
# Iteration 349:
# Train dataset size= 358
# 8
# Iteration 350:
# Train dataset size= 359
# 9
# Iteration 351:
# Train dataset size= 360
# 0
# Iteration 352:
# Train dataset size= 361
# 1
# Iteration 353:
# Train dataset size= 362
# 2
# Iteration 354:
# Train dataset size= 363
# 3
# Iteration 355:
# Train dataset size= 364
# 4
# Iteration 356:
# Train dataset size= 365
# 5
# Iteration 357:
# Train dataset size= 366
# 6
# Iteration 358:
# Train dataset size= 367
# 7
# Iteration 359:
# Train dataset size= 368
# 8
# Iteration 360:
# Train dataset size= 369
# 9
# Iteration 361:
# Train dataset size= 370
# 0
# Iteration 362:
# Train dataset size= 371
# 1
# Iteration 363:
# Train dataset size= 372
# 2
# Iteration 364:
# Train dataset size= 373
# 3
# Iteration 365:
# Train dataset size= 374
# 4
# Iteration 366:
# Train dataset size= 375
# 5
# Iteration 367:
# Train dataset size= 376
# 6
# Iteration 368:
# Train dataset size= 377
# 7
# Iteration 369:
# Train dataset size= 378
# 8
# Iteration 370:
# Train dataset size= 379
# 9
# Iteration 371:
# Train dataset size= 380
# 0
# Iteration 372:
# Train dataset size= 381
# 1
# Iteration 373:
# Train dataset size= 382
# 2
# Iteration 374:
# Train dataset size= 383
# 3
# Iteration 375:
# Train dataset size= 384
# 4
# Iteration 376:
# Train dataset size= 385
# 5
# Iteration 377:
# Train dataset size= 386
# 6
# Iteration 378:
# Train dataset size= 387
# 7
# Iteration 379:
# Train dataset size= 388
# 8
# Iteration 380:
# Train dataset size= 389
# 9
# Iteration 381:
# Train dataset size= 390
# 0
# Iteration 382:
# Train dataset size= 391
# 1
# Iteration 383:
# Train dataset size= 392
# 2
# Iteration 384:
# Train dataset size= 393
# 3
# Iteration 385:
# Train dataset size= 394
# 4
# Iteration 386:
# Train dataset size= 395
# 5
# Iteration 387:
# Train dataset size= 396
# 6
# Iteration 388:
# Train dataset size= 397
# 7
# Iteration 389:
# Train dataset size= 398
# 8
# Iteration 390:
# Train dataset size= 399
# 9
# Iteration 391:
# Train dataset size= 400
# 0
# Iteration 392:
# Train dataset size= 401
# 1
# Iteration 393:
# Train dataset size= 402
# 2
# Iteration 394:
# Train dataset size= 403
# 3
# Iteration 395:
# Train dataset size= 404
# 4
# Iteration 396:
# Train dataset size= 405
# 5
# Iteration 397:
# Train dataset size= 406
# 6
# Iteration 398:
# Train dataset size= 407
# 7
# Iteration 399:
# Train dataset size= 408
# 8
# Iteration 400:
# Train dataset size= 409
# 9
# Iteration 401:
# Train dataset size= 410
# 0
# Iteration 402:
# Train dataset size= 411
# 1
# Iteration 403:
# Train dataset size= 412
# 2
# Iteration 404:
# Train dataset size= 413
# 3
# Iteration 405:
# Train dataset size= 414
# 4
# Iteration 406:
# Train dataset size= 415
# 5
# Iteration 407:
# Train dataset size= 416
# 6
# Iteration 408:
# Train dataset size= 417
# 7
# Iteration 409:
# Train dataset size= 418
# 8
# Iteration 410:
# Train dataset size= 419
# 9
# Iteration 411:
# Train dataset size= 420
# 0
# Iteration 412:
# Train dataset size= 421
# 1
# Iteration 413:
# Train dataset size= 422
# 2
# Iteration 414:
# Train dataset size= 423
# 3
# Iteration 415:
# Train dataset size= 424
# 4
# Iteration 416:
# Train dataset size= 425
# 5
# Iteration 417:
# Train dataset size= 426
# 6
# Iteration 418:
# Train dataset size= 427
# 7
# Iteration 419:
# Train dataset size= 428
# 8
# Iteration 420:
# Train dataset size= 429
# 9
# Iteration 421:
# Train dataset size= 430
# 0
# Iteration 422:
# Train dataset size= 431
# 1
# Iteration 423:
# Train dataset size= 432
# 2
# Iteration 424:
# Train dataset size= 433
# 3
# Iteration 425:
# Train dataset size= 434
# 4
# Iteration 426:
# Train dataset size= 435
# 5
# Iteration 427:
# Train dataset size= 436
# 6
# Iteration 428:
# Train dataset size= 437
# 7
# Iteration 429:
# Train dataset size= 438
# 8
# Iteration 430:
# Train dataset size= 439
# 9
# Iteration 431:
# Train dataset size= 440
# 0
# Iteration 432:
# Train dataset size= 441
# 1
# Iteration 433:
# Train dataset size= 442
# 2
# Iteration 434:
# Train dataset size= 443
# 3
# Iteration 435:
# Train dataset size= 444
# 4
# Iteration 436:
# Train dataset size= 445
# 5
# Iteration 437:
# Train dataset size= 446
# 6
# Iteration 438:
# Train dataset size= 447
# 7
# Iteration 439:
# Train dataset size= 448
# 8
# Iteration 440:
# Train dataset size= 449
# 9
# Iteration 441:
# Train dataset size= 450
# 0
# Iteration 442:
# Train dataset size= 451
# 1
# Iteration 443:
# Train dataset size= 452
# 2
# Iteration 444:
# Train dataset size= 453
# 3
# Iteration 445:
# Train dataset size= 454
# 4
# Iteration 446:
# Train dataset size= 455
# 5
# Iteration 447:
# Train dataset size= 456
# 6
# Iteration 448:
# Train dataset size= 457
# 7
# Iteration 449:
# Train dataset size= 458
# 8
# Iteration 450:
# Train dataset size= 459
# 9
# Iteration 451:
# Train dataset size= 460
# 0
# Iteration 452:
# Train dataset size= 461
# 1
# Iteration 453:
# Train dataset size= 462
# 2
# Iteration 454:
# Train dataset size= 463
# 3
# Iteration 455:
# Train dataset size= 464
# 4
# Iteration 456:
# Train dataset size= 465
# 5
# Iteration 457:
# Train dataset size= 466
# 6
# Iteration 458:
# Train dataset size= 467
# 7
# Iteration 459:
# Train dataset size= 468
# 8
# Iteration 460:
# Train dataset size= 469
# 9
# Iteration 461:
# Train dataset size= 470
# 0
# Iteration 462:
# Train dataset size= 471
# 1
# Iteration 463:
# Train dataset size= 472
# 2
# Iteration 464:
# Train dataset size= 473
# 3
# Iteration 465:
# Train dataset size= 474
# 4
# Iteration 466:
# Train dataset size= 475
# 5
# Iteration 467:
# Train dataset size= 476
# 6
# Iteration 468:
# Train dataset size= 477
# 7
# Iteration 469:
# Train dataset size= 478
# 8
# Iteration 470:
# Train dataset size= 479
# 9
# Iteration 471:
# Train dataset size= 480
# 0
# Iteration 472:
# Train dataset size= 481
# 1
# Iteration 473:
# Train dataset size= 482
# 2
# Iteration 474:
# Train dataset size= 483
# 3
# Iteration 475:
# Train dataset size= 484
# 4
# Iteration 476:
# Train dataset size= 485
# 5
# Iteration 477:
# Train dataset size= 486
# 6
# Iteration 478:
# Train dataset size= 487
# 7
# Iteration 479:
# Train dataset size= 488
# 8
# Iteration 480:
# Train dataset size= 489
# 9
# Iteration 481:
# Train dataset size= 490
# 0
# Iteration 482:
# Train dataset size= 491
# 1
# Iteration 483:
# Train dataset size= 492
# 2
# Iteration 484:
# Train dataset size= 493
# 3
# Iteration 485:
# Train dataset size= 494
# 4
# Iteration 486:
# Train dataset size= 495
# 5
# Iteration 487:
# Train dataset size= 496
# 6
# Iteration 488:
# Train dataset size= 497
# 7
# Iteration 489:
# Train dataset size= 498
# 8
# Iteration 490:
# Train dataset size= 499
# 9
# Iteration 491:
# Train dataset size= 500
# 0
# Iteration 492:
# Train dataset size= 501
# 1
# Iteration 493:
# Train dataset size= 502
# 2
# Iteration 494:
# Train dataset size= 503
# 3
# Iteration 495:
# Train dataset size= 504
# 4
# Iteration 496:
# Train dataset size= 505
# 5
# Iteration 497:
# Train dataset size= 506
# 6
# Iteration 498:
# Train dataset size= 507
# 7
# Iteration 499:
# Train dataset size= 508
# 8
# Iteration 500:
# Train dataset size= 509
# 9
# Iteration 501:
# Train dataset size= 510
# 0
# Iteration 502:
# Train dataset size= 511
# 1
# Iteration 503:
# Train dataset size= 512
# 2
# Iteration 504:
# Train dataset size= 513
# 3
# Iteration 505:
# Train dataset size= 514
# 4
# Iteration 506:
# Train dataset size= 515
# 5
# Iteration 507:
# Train dataset size= 516
# 6
# Iteration 508:
# Train dataset size= 517
# 7
# Iteration 509:
# Train dataset size= 518
# 8
# Iteration 510:
# Train dataset size= 519
# 9
# Iteration 511:
# Train dataset size= 520
# 0
# Iteration 512:
# Train dataset size= 521
# 1
# Iteration 513:
# Train dataset size= 522
# 2
# Iteration 514:
# Train dataset size= 523
# 3
# Iteration 515:
# Train dataset size= 524
# 4
# Iteration 516:
# Train dataset size= 525
# 5
# Iteration 517:
# Train dataset size= 526
# 6
# Iteration 518:
# Train dataset size= 527
# 7
# Iteration 519:
# Train dataset size= 528
# 8
# Iteration 520:
# Train dataset size= 529
# 9
# Iteration 521:
# Train dataset size= 530
# 0
# Iteration 522:
# Train dataset size= 531
# 1
# Iteration 523:
# Train dataset size= 532
# 2
# Iteration 524:
# Train dataset size= 533
# 3
# Iteration 525:
# Train dataset size= 534
# 4
# Iteration 526:
# Train dataset size= 535
# 5
# Iteration 527:
# Train dataset size= 536
# 6
# Iteration 528:
# Train dataset size= 537
# 7
# Iteration 529:
# Train dataset size= 538
# 8
# Iteration 530:
# Train dataset size= 539
# 9
# Iteration 531:
# Train dataset size= 540
# 0
# Iteration 532:
# Train dataset size= 541
# 1
# Iteration 533:
# Train dataset size= 542
# 2
# Iteration 534:
# Train dataset size= 543
# 3
# Iteration 535:
# Train dataset size= 544
# 4
# Iteration 536:
# Train dataset size= 545
# 5
# Iteration 537:
# Train dataset size= 546
# 6
# Iteration 538:
# Train dataset size= 547
# 7
# Iteration 539:
# Train dataset size= 548
# 8
# Iteration 540:
# Train dataset size= 549
# 9
# Iteration 541:
# Train dataset size= 550
# 0
# Iteration 542:
# Train dataset size= 551
# 1
# Iteration 543:
# Train dataset size= 552
# 2
# Iteration 544:
# Train dataset size= 553
# 3
# Iteration 545:
# Train dataset size= 554
# 4
# Iteration 546:
# Train dataset size= 555
# 5
# Iteration 547:
# Train dataset size= 556
# 6
# Iteration 548:
# Train dataset size= 557
# 7
# Iteration 549:
# Train dataset size= 558
# 8
# Iteration 550:
# Train dataset size= 559
# 9
# Iteration 551:
# Train dataset size= 560
# 0
# Iteration 552:
# Train dataset size= 561
# 1
# Iteration 553:
# Train dataset size= 562
# 2
# Iteration 554:
# Train dataset size= 563
# 3
# Iteration 555:
# Train dataset size= 564
# 4
# Iteration 556:
# Train dataset size= 565
# 5
# Iteration 557:
# Train dataset size= 566
# 6
# Iteration 558:
# Train dataset size= 567
# 7
# Iteration 559:
# Train dataset size= 568
# 8
# Iteration 560:
# Train dataset size= 569
# 9
# Iteration 561:
# Train dataset size= 570
# 0
# Iteration 562:
# Train dataset size= 571
# 1
# Iteration 563:
# Train dataset size= 572
# 2
# Iteration 564:
# Train dataset size= 573
# 3
# Iteration 565:
# Train dataset size= 574
# 4
# Iteration 566:
# Train dataset size= 575
# 5
# Iteration 567:
# Train dataset size= 576
# 6
# Iteration 568:
# Train dataset size= 577
# 7
# Iteration 569:
# Train dataset size= 578
# 8
# Iteration 570:
# Train dataset size= 579
# 9
# Iteration 571:
# Train dataset size= 580
# 0
# Iteration 572:
# Train dataset size= 581
# 1
# Iteration 573:
# Train dataset size= 582
# 2
# Iteration 574:
# Train dataset size= 583
# 3
# Iteration 575:
# Train dataset size= 584
# 4
# Iteration 576:
# Train dataset size= 585
# 5
# Iteration 577:
# Train dataset size= 586
# 6
# Iteration 578:
# Train dataset size= 587
# 7
# Iteration 579:
# Train dataset size= 588
# 8
# Iteration 580:
# Train dataset size= 589
# 9
# Iteration 581:
# Train dataset size= 590
# 0
# Iteration 582:
# Train dataset size= 591
# 1
# Iteration 583:
# Train dataset size= 592
# 2
# Iteration 584:
# Train dataset size= 593
# 3
# Iteration 585:
# Train dataset size= 594
# 4
# Iteration 586:
# Train dataset size= 595
# 5
# Iteration 587:
# Train dataset size= 596
# 6
# Iteration 588:
# Train dataset size= 597
# 7
# Iteration 589:
# Train dataset size= 598
# 8
# Iteration 590:
# Train dataset size= 599
# 9
# Iteration 591:
# Train dataset size= 600
# 0
# Iteration 592:
# Train dataset size= 601
# 1
# Iteration 593:
# Train dataset size= 602
# 2
# Iteration 594:
# Train dataset size= 603
# 3
# Iteration 595:
# Train dataset size= 604
# 4
# Iteration 596:
# Train dataset size= 605
# 5
# Iteration 597:
# Train dataset size= 606
# 6
# Iteration 598:
# Train dataset size= 607
# 7
# Iteration 599:
# Train dataset size= 608
# 8
# Iteration 600:
# Train dataset size= 609
# 9
# Iteration 601:
# Train dataset size= 610
# 0
# Iteration 602:
# Train dataset size= 611
# 1
# Iteration 603:
# Train dataset size= 612
# 2
# Iteration 604:
# Train dataset size= 613
# 3
# Iteration 605:
# Train dataset size= 614
# 4
# Iteration 606:
# Train dataset size= 615
# 5
# Iteration 607:
# Train dataset size= 616
# 6
# Iteration 608:
# Train dataset size= 617
# 7
# Iteration 609:
# Train dataset size= 618
# 8
# Iteration 610:
# Train dataset size= 619
# 9
# Iteration 611:
# Train dataset size= 620
# 0
# Iteration 612:
# Train dataset size= 621
# 1
# Iteration 613:
# Train dataset size= 622
# 2
# Iteration 614:
# Train dataset size= 623
# 3
# Iteration 615:
# Train dataset size= 624
# 4
# Iteration 616:
# Train dataset size= 625
# 5
# Iteration 617:
# Train dataset size= 626
# 6
# Iteration 618:
# Train dataset size= 627
# 7
# Iteration 619:
# Train dataset size= 628
# 8
# Iteration 620:
# Train dataset size= 629
# 9
# Iteration 621:
# Train dataset size= 630
# 0
# Iteration 622:
# Train dataset size= 631
# 1
# Iteration 623:
# Train dataset size= 632
# 2
# Iteration 624:
# Train dataset size= 633
# 3
# Iteration 625:
# Train dataset size= 634
# 4
# Iteration 626:
# Train dataset size= 635
# 5
# Iteration 627:
# Train dataset size= 636
# 6
# Iteration 628:
# Train dataset size= 637
# 7
# Iteration 629:
# Train dataset size= 638
# 8
# Iteration 630:
# Train dataset size= 639
# 9
# Iteration 631:
# Train dataset size= 640
# 0
# Iteration 632:
# Train dataset size= 641
# 1
# Iteration 633:
# Train dataset size= 642
# 2
# Iteration 634:
# Train dataset size= 643
# 3
# Iteration 635:
# Train dataset size= 644
# 4
# Iteration 636:
# Train dataset size= 645
# 5
# Iteration 637:
# Train dataset size= 646
# 6
# Iteration 638:
# Train dataset size= 647
# 7
# Iteration 639:
# Train dataset size= 648
# 8
# Iteration 640:
# Train dataset size= 649
# 9
# Iteration 641:
# Train dataset size= 650
# 0
# Iteration 642:
# Train dataset size= 651
# 1
# Iteration 643:
# Train dataset size= 652
# 2
# Iteration 644:
# Train dataset size= 653
# 3
# Iteration 645:
# Train dataset size= 654
# 4
# Iteration 646:
# Train dataset size= 655
# 5
# Iteration 647:
# Train dataset size= 656
# 6
# Iteration 648:
# Train dataset size= 657
# 7
# Iteration 649:
# Train dataset size= 658
# 8
# Iteration 650:
# Train dataset size= 659
# 9
# Iteration 651:
# Train dataset size= 660
# 0
# Iteration 652:
# Train dataset size= 661
# 1
# Iteration 653:
# Train dataset size= 662
# 2
# Iteration 654:
# Train dataset size= 663
# 3
# Iteration 655:
# Train dataset size= 664
# 4
# Iteration 656:
# Train dataset size= 665
# 5
# Iteration 657:
# Train dataset size= 666
# 6
# Iteration 658:
# Train dataset size= 667
# 7
# Iteration 659:
# Train dataset size= 668
# 8
# Iteration 660:
# Train dataset size= 669
# 9
# Iteration 661:
# Train dataset size= 670
# 0
# Iteration 662:
# Train dataset size= 671
# 1
# Iteration 663:
# Train dataset size= 672
# 2
# Iteration 664:
# Train dataset size= 673
# 3
# Iteration 665:
# Train dataset size= 674
# 4
# Iteration 666:
# Train dataset size= 675
# 5
# Iteration 667:
# Train dataset size= 676
# 6
# Iteration 668:
# Train dataset size= 677
# 7
# Iteration 669:
# Train dataset size= 678
# 8
# Iteration 670:
# Train dataset size= 679
# 9
# Iteration 671:
# Train dataset size= 680
# 0
# Iteration 672:
# Train dataset size= 681
# 1
# Iteration 673:
# Train dataset size= 682
# 2
# Iteration 674:
# Train dataset size= 683
# 3
# Iteration 675:
# Train dataset size= 684
# 4
# Iteration 676:
# Train dataset size= 685
# 5
# Iteration 677:
# Train dataset size= 686
# 6
# Iteration 678:
# Train dataset size= 687
# 7
# Iteration 679:
# Train dataset size= 688
# 8
# Iteration 680:
# Train dataset size= 689
# 9
# Iteration 681:
# Train dataset size= 690
# 0
# Iteration 682:
# Train dataset size= 691
# 1
# Iteration 683:
# Train dataset size= 692
# 2
# Iteration 684:
# Train dataset size= 693
# 3
# Iteration 685:
# Train dataset size= 694
# 4
# Iteration 686:
# Train dataset size= 695
# 5
# Iteration 687:
# Train dataset size= 696
# 6
# Iteration 688:
# Train dataset size= 697
# 7
# Iteration 689:
# Train dataset size= 698
# 8
# Iteration 690:
# Train dataset size= 699
# 9
# Iteration 691:
# Train dataset size= 700
# 0
# Iteration 692:
# Train dataset size= 701
# 1
# Iteration 693:
# Train dataset size= 702
# 2
# Iteration 694:
# Train dataset size= 703
# 3
# Iteration 695:
# Train dataset size= 704
# 4
# Iteration 696:
# Train dataset size= 705
# 5
# Iteration 697:
# Train dataset size= 706
# 6
# Iteration 698:
# Train dataset size= 707
# 7
# Iteration 699:
# Train dataset size= 708
# 8
# Iteration 700:
# Train dataset size= 709
# 9
# Iteration 701:
# Train dataset size= 710
# 0
# Iteration 702:
# Train dataset size= 711
# 1
# Iteration 703:
# Train dataset size= 712
# 2
# Iteration 704:
# Train dataset size= 713
# 3
# Iteration 705:
# Train dataset size= 714
# 4
# Iteration 706:
# Train dataset size= 715
# 5
# Iteration 707:
# Train dataset size= 716
# 6
# Iteration 708:
# Train dataset size= 717
# 7
# Iteration 709:
# Train dataset size= 718
# 8
# Iteration 710:
# Train dataset size= 719
# 9
# Iteration 711:
# Train dataset size= 720
# 0
# Iteration 712:
# Train dataset size= 721
# 1
# Iteration 713:
# Train dataset size= 722
# 2
# Iteration 714:
# Train dataset size= 723
# 3
# Iteration 715:
# Train dataset size= 724
# 4
# Iteration 716:
# Train dataset size= 725
# 5
# Iteration 717:
# Train dataset size= 726
# 6
# Iteration 718:
# Train dataset size= 727
# 7
# Iteration 719:
# Train dataset size= 728
# 8
# Iteration 720:
# Train dataset size= 729
# 9
# Iteration 721:
# Train dataset size= 730
# 0
# Iteration 722:
# Train dataset size= 731
# 1
# Iteration 723:
# Train dataset size= 732
# 2
# Iteration 724:
# Train dataset size= 733
# 3
# Iteration 725:
# Train dataset size= 734
# 4
# Iteration 726:
# Train dataset size= 735
# 5
# Iteration 727:
# Train dataset size= 736
# 6
# Iteration 728:
# Train dataset size= 737
# 7
# Iteration 729:
# Train dataset size= 738
# 8
# Iteration 730:
# Train dataset size= 739
# 9
# Iteration 731:
# Train dataset size= 740
# 0
# Iteration 732:
# Train dataset size= 741
# 1
# Iteration 733:
# Train dataset size= 742
# 2
# Iteration 734:
# Train dataset size= 743
# 3
# Iteration 735:
# Train dataset size= 744
# 4
# Iteration 736:
# Train dataset size= 745
# 5
# Iteration 737:
# Train dataset size= 746
# 6
# Iteration 738:
# Train dataset size= 747
# 7
# Iteration 739:
# Train dataset size= 748
# 8
# Iteration 740:
# Train dataset size= 749
# 9
# Iteration 741:
# Train dataset size= 750
# 0
# Iteration 742:
# Train dataset size= 751
# 1
# Iteration 743:
# Train dataset size= 752
# 2
# Iteration 744:
# Train dataset size= 753
# 3
# Iteration 745:
# Train dataset size= 754
# 4
# Iteration 746:
# Train dataset size= 755
# 5
# Iteration 747:
# Train dataset size= 756
# 6
# Iteration 748:
# Train dataset size= 757
# 7
# Iteration 749:
# Train dataset size= 758
# 8
# Iteration 750:
# Train dataset size= 759
# 9
# Iteration 751:
# Train dataset size= 760
# 0
# Iteration 752:
# Train dataset size= 761
# 1
# Iteration 753:
# Train dataset size= 762
# 2
# Iteration 754:
# Train dataset size= 763
# 3
# Iteration 755:
# Train dataset size= 764
# 4
# Iteration 756:
# Train dataset size= 765
# 5
# Iteration 757:
# Train dataset size= 766
# 6
# Iteration 758:
# Train dataset size= 767
# 7
# Iteration 759:
# Train dataset size= 768
# 8
# Iteration 760:
# Train dataset size= 769
# 9
# Iteration 761:
# Train dataset size= 770
# 0
# Iteration 762:
# Train dataset size= 771
# 1
# Iteration 763:
# Train dataset size= 772
# 2
# Iteration 764:
# Train dataset size= 773
# 3
# Iteration 765:
# Train dataset size= 774
# 4
# Iteration 766:
# Train dataset size= 775
# 5
# Iteration 767:
# Train dataset size= 776
# 6
# Iteration 768:
# Train dataset size= 777
# 7
# Iteration 769:
# Train dataset size= 778
# 8
# Iteration 770:
# Train dataset size= 779
# 9
# Iteration 771:
# Train dataset size= 780
# 0
# Iteration 772:
# Train dataset size= 781
# 1
# Iteration 773:
# Train dataset size= 782
# 2
# Iteration 774:
# Train dataset size= 783
# 3
# Iteration 775:
# Train dataset size= 784
# 4
# Iteration 776:
# Train dataset size= 785
# 5
# Iteration 777:
# Train dataset size= 786
# 6
# Iteration 778:
# Train dataset size= 787
# 7
# Iteration 779:
# Train dataset size= 788
# 8
# Iteration 780:
# Train dataset size= 789
# 9
# Iteration 781:
# Train dataset size= 790
# 0
# Iteration 782:
# Train dataset size= 791
# 1
# Iteration 783:
# Train dataset size= 792
# 2
# Iteration 784:
# Train dataset size= 793
# 3
# Iteration 785:
# Train dataset size= 794
# 4
# Iteration 786:
# Train dataset size= 795
# 5
# Iteration 787:
# Train dataset size= 796
# 6
# Iteration 788:
# Train dataset size= 797
# 7
# Iteration 789:
# Train dataset size= 798
# 8
# Iteration 790:
# Train dataset size= 799
# 9
# Iteration 791:
# Train dataset size= 800
# 0
# Iteration 792:
# Train dataset size= 801
# 1
# Iteration 793:
# Train dataset size= 802
# 2
# Iteration 794:
# Train dataset size= 803
# 3
# Iteration 795:
# Train dataset size= 804
# 4
# Iteration 796:
# Train dataset size= 805
# 5
# Iteration 797:
# Train dataset size= 806
# 6
# Iteration 798:
# Train dataset size= 807
# 7
# Iteration 799:
# Train dataset size= 808
# 8
# Iteration 800:
# Train dataset size= 809
# 9
# Iteration 801:
# Train dataset size= 810
# 0
# Iteration 802:
# Train dataset size= 811
# 1
# Iteration 803:
# Train dataset size= 812
# 2
# Iteration 804:
# Train dataset size= 813
# 3
# Iteration 805:
# Train dataset size= 814
# 4

# %% [markdown]
# # Plots

# %%
np.savez('train_dataset_KNN', x_train=x_train_classifer, y_train=y_train_classifer)

# %%
plt.plot(hist_clf_train_f1)
plt.xlabel("Iteration")
plt.ylabel("F1-score")
plt.title("Classifier Train F1-score")

# %%
plt.plot(hist_clf_test_f1)
plt.xlabel("Iteration")
plt.ylabel("F1-score")
plt.title("Classifier Test F1-score")
# plt.yscale('log')
plt.show()
